# %%
import pandas as pd
import numpy as np

# %%
# load json file
df = pd.read_json('output-data/data.json')

# %%
df
# Out:
#                               name                      mother     seat_no  \
# 0    AASHUTOSH SANJAYRAO GUNTURKAR  SHITAL SANJAYRAO GUNTURKAR  S190243001
# 1              ADMANE PARTH SUDHIR        RUPALI SUDHIR ADMANE  S190243002
# 2                       ALKA GUPTA                URMILA GUPTA  S190243003
# 3              AMUP AKASH HANUMANT        AMUP SAVITA HANUMANT  S190243004
# 4                       ANIKET ROY                  NAMITA ROY  S190243005
# ..                             ...                         ...         ...
# 231            YERNE MAYANK MAHESH             SULOCHANA YERNE  S190243232
# 232          ZAMARE SARVESH DINKAR        YOGITA DINKAR ZAMARE  S190243233
# 233          ZAWARE SARTHAK NAMDEO                     SUCHETA  S190243234
# 234        BHOSALE JAYRAJ JAYSINGH   BHOSALE JAYSHREE JAYSINGH  S190243235
# 235                 SHADAB HUSSAIN                     AFSHANA  S190243236
#
#            prn                                               sem1  \
# ...
